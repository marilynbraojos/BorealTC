# %%
from utils.models import MambaClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from utils.models import MambaClassifier
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/doctorate/ssdl/terrain_adaptation/src/learning_based_terrain_id/borealtc/BorealTC/utils/models.py:45
#      37 from utils.constants import ch_cols, imu_dim, pro_dim
#      38 from utils.datamodule import (
#      39     MCSDataModule,
#      40     TemporalDataModule,
#      41     MambaDataModule,
#      42     MambaDataModuleCombined,
#      43 )
# ---> 45 from mamba_ssm.models.mixer_seq_simple import create_block
#      47 if TYPE_CHECKING:
#      48     ExperimentData = dict[str, pd.DataFrame | np.ndarray]
#
# ModuleNotFoundError: No module named 'mamba_ssm'
