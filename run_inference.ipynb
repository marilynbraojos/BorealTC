# %% [markdown]
# <a href="https://colab.research.google.com/github/marilynbraojos/BorealTC/blob/python/run_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/marilynbraojos/BorealTC.git
# Out:
# fatal: destination path 'BorealTC' already exists and is not an empty directory.

# %%
# %cd BorealTC/
# Out:
# /content/BorealTC

# %%
# !pip install torch torchvision torchaudio lightning matplotlib pandas scikit-learn librosa

# %%
# !pip install pipeline

# %%
# import os
# os.environ['DATASET'] = 'husky'

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 3.27 KiB | 3.27 MiB/s, done.
# From https://github.com/marilynbraojos/BorealTC
#    457df6a..225cd90  python     -> origin/python
# Updating 457df6a..225cd90
# Fast-forward
#  run_inference.ipynb | 347 +++++++++++++++++++++++++++++++++++++++++++---------
#  1 file changed, 291 insertions(+), 56 deletions(-)

# %%
# !python cnn_train.py
# Out:
# Training on husky with ['CNN']...
# Training models for a sampling window of 1.7 seconds
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training CNN model with 1.7 seconds...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Traceback (most recent call last):
#   File "/content/BorealTC/cnn_train.py", line 205, in <module>
#     ) = preprocessing.apply_multichannel_spectogram(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/BorealTC/utils/preprocessing.py", line 749, in apply_multichannel_spectogram
#     frequency.multichannel_spectrogram(
#   File "/content/BorealTC/utils/frequency.py", line 32, in multichannel_spectrogram
#     mcs, _, tgrid, fgrid = spectrogram(sens_data, sf, mw, tw, to, hamming)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/BorealTC/utils/frequency.py", line 142, in spectrogram
#     mag, phase, freq = DFT(win, sampling_freq, hamming)
# ...
