# %% [markdown]
# <a href="https://colab.research.google.com/github/marilynbraojos/BorealTC/blob/python/running_model_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/marilynbraojos/BorealTC.git
# Out:
# Cloning into 'BorealTC'...
# remote: Enumerating objects: 3129, done.
# remote: Counting objects: 100% (460/460), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 3129 (delta 314), reused 407 (delta 272), pack-reused 2669 (from 1)
# Receiving objects: 100% (3129/3129), 587.07 MiB | 27.79 MiB/s, done.
# Resolving deltas: 100% (1685/1685), done.

# %%
# %cd BorealTC

# %%
# !pip install -r requirements.txt
