# %% [markdown]
# <a href="https://colab.research.google.com/github/marilynbraojos/BorealTC/blob/python/running_model_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/marilynbraojos/BorealTC.git
# Out:
# fatal: destination path 'BorealTC' already exists and is not an empty directory.

# %%
# %cd BorealTC
# Out:
# /content/BorealTC

# %%
# !pip install -r requirements.txt
# Out:
# Collecting git+https://github.com/willGuimont/pipeline (from -r requirements.txt (line 21))
#   Cloning https://github.com/willGuimont/pipeline to /tmp/pip-req-build-oyfgwsxp
#   Running command git clone --filter=blob:none --quiet https://github.com/willGuimont/pipeline /tmp/pip-req-build-oyfgwsxp
#   Resolved https://github.com/willGuimont/pipeline to commit 4b2dfed780f98daaf506e510876e0a3db8c82c21
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (18.1.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (7.34.0)
# Collecting jupyterlab (from -r requirements.txt (line 9))
#   Using cached jupyterlab-4.4.10-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (1.6.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.23.0+cu126)
# Collecting lightning (from -r requirements.txt (line 15))
#   Using cached lightning-2.5.6-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (2.19.0)
# Collecting torch-metrics (from -r requirements.txt (line 17))
#   Using cached torch_metrics-1.1.7.tar.gz (1.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (0.8.1)
# Collecting mamba-ssm (from -r requirements.txt (line 20))
#   Using cached mamba_ssm-2.2.6.post3.tar.gz (113 kB)
